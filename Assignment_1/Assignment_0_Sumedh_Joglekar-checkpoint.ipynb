# %% [markdown]
# # Assignment 0 - Data and Visualization
# ## <font color="blue"> Name :- Sumedh Joglekar </font> &emsp; &emsp; &emsp;<font color="blue"> Student_ID :- 801084301 </font>

# %% [markdown]
# # I. Introduction:-
#
# __Aim :-__
# 1. Aim of this assignemt was to get familiar with different tools such as Python, numpy, matplotlib, pandas, Jupyter notebook.
# 2. Visualize two datasets one for regression and one for classification. We were required to choose the data with minimum 10,000 samples and more than 10 feature values.
#
# __Regression and Classification are the types of Supervised Machine Learning.__
#
# __Regression:-__
# - Regression is a form of predictive modelling which investigates the relationship between two variables.
# - Regression can be used to predict the trends in an data based on the available data or historic data.
# - There are different types of regressions namely - Linear Regression, Logistic Regression, Polynomial Regression, Stepwise Regression, etc.
#
# __Classification:-__
# - In classification the data is categorized under different labels according to suitable features and then the labels are predicted for the data.
# - There are different algorithms such as KNN, Naive Bayes, Decision Tree which can be used in order to classify the given data.

# %% [markdown]
# # II. Review:-
#
# ## 1. Linear Algebra
#
# __Mathematical objects involved in the linear algebra:-__
#
# __* Scalars, Vectors, Matrices, Tensors__
#
#     1. Scalars - They are the single numbers.E.g. scalar can be real valued or natural number.
#     2. Vectors - It is an array of numbers arranged in some order. vectors as space pointswith each element giving the coordinate along a diﬀerent axis.
#     3. Matrices - A matrix is a 2-D array of numbers, each number are identiﬁed by two indices.
#     4. Tensors - Array of numbers arranged on a regular grid with avariable number of axes is known as a tensor.
# - Transpose is one of the important operation in the matrices manipualtion and it is widely used in machine learning. Representation of the transpose matrices:-
#    $$ (A^T)_i,_j= A_j,_i $$
# - Matrices of the same shape can be added directly using simple matrices addition.
# $$(C)_i,_j= (A)_i,_j+ (B)_i,_j$$
#
# __* Multiplication of Matrices and vectors__
#
# Product of the matrices can be done when matrices A has same number of columns equivalent to the rows of the B. If A has MxN and B has NxO then the output will have shape equal to MxO.
# $$(C)_i,_j=\sum_{}{}(A)_i,_k(B)_k,_j$$
#
# __* Identity and Inverse Matrices__
#
# - An identity matrix is a square matrix that does not change a vector when multiplied. Identity matrices only holds the diagonal elements with value equal to '1'. As a result when matrix multiplication is done, we get the original matrices back as a result.
# - The matrix inverse of A is denoted as $$A^{−1}$$
# - It is deﬁned as the matrix such that $$ A^{−1} A = I_n$$
#
# __* Linear Dependence and Span__
#
# Vectors is said to be linearly dependent if at least one of the vectors in the set can be defined as a linear combination of the others; if no vector in the set can be written in terms of other, then the vectors are said to be linearly independent.
#
# Square matrix is the matrix which has same number of rows and columns. Left inverse and right inverse of sqare matrices are same.
#
# The span of a set of vectors is the set of all points retrievable by linear combination of the main(original) vectors.
#
# __* Norms__
#     - Used to measure size of a vector.
#     - There are disserent forms of norms which are widely used in depp learngin. Euclidean norm, max norm, Frobenius norm
#     are some of the tyoe of norms.
#
# - Diagonal Matrix : It is matrix in which all the values are zeros except for diagonal values.
# - An orthogonal matrix is a square matrix whose rows are mutually orthonormal and whose columns are mutually orthonormal.
#
# __* Eigendecomposition__
#
# - Decomposition of the matrix into eigen vectors and eigen values.
# - An eigenvector of a square matrix A is a non-zero vector v such that multiplication by A alters only the scale of v:Av = λv, where λ = eigen value corresponding to eigenvector.
#
# __* Single Valued Decomposition__
#
# - In the single valued decomposition, the matrix is divided into single value and single vector.
#
# __* Principal Components Analysis__
#
# - Principal component analysis (PCA) is a technique used to concentrate on variation of data. It is also used detect strong patterns in a dataset.
#
# ## 2. Probability Theory
#
# __* Random Variables__
# - Randim variables are the variables that can take any values randomly.They can be discrete or continuous.
#
# __* Discrete Variables and Probability Mass Functions__
#
# - Probability distribution over discrete variables is know as probability mass function(PMF).
# - Probability mass function can be applied on multiple variables, this type of probability distribution is know as joint probability distribution.
#
# __* Properties needs to be satisfied by random variable in order to be PMF:-__
#     1. The domain of the PMF must be the set of all possible states f=if x.
#     2. Probabilty of occurence of events alywas lie in between 0 and 1. (0 ≤ P(x) ≤ 1)
#     3. Summation of the all events from the domain must be equal to '1'.
#
# __* Marginal Probability Distribution__
#
#  It is the probability of occurence of any single event independent on another one is known as marginal probability distribution.
#
# __* Conditional Probability__
#
# Probability of occurence of any event given that another event has alreadt occured, is called as conditional probability.
#  $p\left(x\mid y\right)=  \frac{p(x,y)}{p(y)}$
#
# __* The Chain Rule of Conditional Probabilities__
#
# Any joint probability distribution over many random variables can be decomposed into conditional distributions over only one variable. Using chain rule we can reduce the computation required.
#
# __* Independence and Conditional Independence__
#
# Two random variables x and y are independent, if their probability distribution can be expressed as a product of two factors, one involving only x and one involving only y.
#
# __* Expectation, Variance and Covariance__
#
# Expectation :- This represents the mean of all given inputs.
# Variance :- The variance of a discrete random variable X measures the spread, or variability, of the distribution.
# Covariance :- Covariance gives the information about how closely two variables are linearly related to each other.
#
# Commonly used Probabilistic Distribution in Machine Learning are :-
# - Bernoulli Distribution
# - Multinoulli Distribution
# - Gaussian Distribution
# - Exponential and Laplace Distributions
# - Dirac Distribution
# - Empirical Distribution
#
# __* Bayes' Rule__
#
# - Bays rule is used when conditional probability needs to be computed.
# - Formula :-
#  $p\left(x\mid y\right)= \frac{p(x) p\left(y\mid x\right)}{p(y)}$
#
# __* Information Theory__
#
# - In the machine learning, we can implement information theory to continuous variables where message length interpretations are not necessary.
#
# __* Kullback–Leibler divergence__
# - Kullback–Leibler divergence is a measure of how one of the probability distribution is different from a second one, considering the same probability distribution.
#
# __* Structured Probabilistic Model__
#
# Two types of structured probabilistic model:-
# 1. Directed Model - Directed models use graphs with directed edges, and represents factorizations into conditional probability distributions.
# 2. Undirected Model - Undirected models use graphs with undirected edges, represents factorizations into a set of function.

# %% [markdown]
# # III. Data
#
# __Below are the datasets that I will be considering for the regression and classification__
#
# 1. For the regression, I have chosen Avocado Price data, which has the information about avocado price, total number of avocados sold, different type of bags and different categories of avocado from multiple US Markets.
#
# 2. For the secord visualization, I have taken dataset of Crimes in Chicago. In this dataset there are different features such as type of crime, year of crime, location, district, arrest.

# %% [markdown]
# # 1. Introduction of data for regression & source
#
# - Dataset contains the historical data on avocado prices and sales volume in multiple US markets from 2015 to 2018.
# - The Average Price of avocados in the table reflects a per unit cost, even when multiple avocados units are sold in bags.
# - The Product Lookup codes (PLU’s) in the table are only for Hass avocados
#
# ### Data Observation:
#
# __Below is the description of the various variables present in the data :__
#
# 1. Date - The date of the incident
# 2. AveragePrice - the average price of a avocado
# 3. type - conventional or organic
# 4. year - the year
# 5. Region - the city or region of the incident
# 6. Total Volume - Total number of avocados sold
# 7. 4046 - Total number of avocados with PLU 4046 sold :- Small Hass
# 8. 4225 - Total number of avocados with PLU 4225 sold :- Large Hass
# 9. 4770 - Total number of avocados with PLU 4770 sold :- Extra Large Hass
#
# ### Source :
#
# https://www.kaggle.com/neuromusic/avocado-prices
#
# ## 1. Reading the data
#
# Here I am reading the data from CSV file with the use of pandas read_csv function.
#
# P.S. :- Place the file path in read_csv function while running the code so that csv file will get read.

# %%
### Importing the required libraries ####
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
#########
#print("Reading the file :- ")
#print(os.listdir("D:/sum/Its Study Time !!!/Academic/M.S/Spring_2019/Machine Learning/Assignment1/avocado-prices/"))
###################
data = pd.read_csv("avocado.csv", encoding='utf-8')# Place the file location here.
data.head(10)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5           5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6           6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7           7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8           8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9           9  2015-10-25          1.07      74338.76   842.40   64757.44
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# ...

# %% [markdown]
# ## 2. Preprocessing of the data
#
# In order to do the pre-processiong task, I have followed below steps:-
# 1. Check for the null values, if any null data is present either remove the entries(if entries are less in number) or replace the null value with mean of the that category. If any of this method is not suitable then think for other pre-rocessing tasks.
# 2. Eliminate irrelevant columns so that the visualization will be easier.
# 3. Rename the column names of PLU's with the bag size so that data interpretention can be more convinient.
# 4. Separated out the 'date' column into 'year' as it will be easy to visualize the data distribution over different years.
# 5. By initial observation, it was found that there is an overlapping of the data in the given dataset and hence removed the overlapping entries from the dataset.

# %%
# Pre Processing the data.. Splitting the column Date and taking out only year from it ########
################# 1. Checking for thr null Values ################
print(data.isnull().sum())
################# 2. Dropping unwanted column Unnamed ################
data.rename( columns={'Unnamed: 0':'new column name'}, inplace=True )
data = data.drop('new column name', axis=1)
################# 3. Renaming the columns so that visualization will be more convinient ################
data = data.rename(index=str, columns={"4046" : "Small_Hass", "4225" : "Large_Hass", "4770" : "XLarge_Hass"})
data.head()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64
#          Date  AveragePrice  Total Volume  Small_Hass  Large_Hass  \
# 0  2015-12-27          1.33      64236.62     1036.74    54454.85
# 1  2015-12-20          1.35      54876.98      674.28    44638.81
# 2  2015-12-13          0.93     118220.22      794.70   109149.67
# 3  2015-12-06          1.08      78992.15     1132.00    71976.41
# 4  2015-11-29          1.28      51039.60      941.48    43838.39
#
#    XLarge_Hass  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0        48.16     8696.87     8603.62       93.25          0.0  conventional
# 1        58.33     9505.56     9408.07       97.49          0.0  conventional
# ...

# %%
########### 4.Separating out Year from  Date column ########### 
data
new_data = data["Date"].str.split("-", n = 2, expand = True) 
data["Year"] = new_data[0]
data.drop(columns=["Date"], inplace = True)
data.head()
#new_data
# Out:
#    AveragePrice  Total Volume  Small_Hass  Large_Hass  XLarge_Hass  \
# 0          1.33      64236.62     1036.74    54454.85        48.16
# 1          1.35      54876.98      674.28    44638.81        58.33
# 2          0.93     118220.22      794.70   109149.67       130.50
# 3          1.08      78992.15     1132.00    71976.41        72.58
# 4          1.28      51039.60      941.48    43838.39        75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Year
# 0  Albany  2015
# 1  Albany  2015
# 2  Albany  2015
# 3  Albany  2015
# 4  Albany  2015

# %% [markdown]
# ### Note :-
# Aftere observing the data,it is found that there is overlapping between data, e.g there is a data of California as well as SanFrancisco. We need to remove the overlapping data to have correct visualization. Hence removing overlapping data by dropping certain rows.

# %%
############ 5. Removing the overlapping data. #############
regionsToDrop = ['California', 'GreatLakes', 'Midsouth', 'NewYork', 'Northeast', 'SouthCarolina', 
                   'Plains', 'SouthCentral', 'Southeast', 'TotalUS', 'West']
data = data[~data.region.isin(regionsToDrop)] # Taking compliment of data not present in regionsToDrop
data.head()
# Out:
#    AveragePrice  Total Volume  Small_Hass  Large_Hass  XLarge_Hass  \
# 0          1.33      64236.62     1036.74    54454.85        48.16
# 1          1.35      54876.98      674.28    44638.81        58.33
# 2          0.93     118220.22      794.70   109149.67       130.50
# 3          1.08      78992.15     1132.00    71976.41        72.58
# 4          1.28      51039.60      941.48    43838.39        75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Year
# 0  Albany  2015
# 1  Albany  2015
# 2  Albany  2015
# 3  Albany  2015
# 4  Albany  2015

# %% [markdown]
# ## 3. Visualization of the data

# %%
### Plotting the distribution of the average price, in order to find rhe average price of Avocado.###

sns.distplot(data["AveragePrice"],axlabel="Distribution of average price")

# %% [markdown]
# ### Observation :-
#
# From the above distribution graph it can be interpreted that the average price of avocado falls in between 1.0 and 1.75.

# %% [markdown]
# Taking 5 cities and checking the pattern in which the prices are increased. To do that plotting the line graph for all years with average price.

# %%
############ Average Price of Avocado According to the Year for top 5 highest average prices ##########
area_list=list(data.region.unique())
unique_years = list(data.year.unique())
area_averageprice_ratio=[]
for i in area_list:
    x=data[data['region']==i]
    area_averageprice_rate=sum(x['AveragePrice'])/len(x)
    area_averageprice_ratio.append(area_averageprice_rate)
#area_averageprice_ratio = sorted(area_averageprice_ratio,reverse=True)
#print(area_averageprice_ratio)
df=pd.DataFrame({'area_list':area_list,'area_averageprice_ratio':area_averageprice_ratio})
new_index=df['area_averageprice_ratio'].sort_values(ascending=False).index.values
sorted_data=df.reindex(new_index)
#print(sorted_data.area_list[int(sorted_data.index[0])])
plt.figure(figsize=(10,10))
test1=[]
print("Top 5 Contries:- ")
print("----------------")
for i in range(0,5):
    avg_column_cali= data[data["region"]==sorted_data.area_list[int(sorted_data.index[i])]]
    print(sorted_data.area_list[int(sorted_data.index[i])])
    #avg_column_cali = data[data["region"]==area_list[i]]                              
    #print(avg_column_cali)
    avg_per_year_cali = avg_column_cali.groupby('year').aggregate('mean')
    #data.year
    #print(avg_per_year_cali.AveragePrice)
    test1.append(sorted_data.area_list[sorted_data.index[i]])
    plt.plot(unique_years,avg_per_year_cali.AveragePrice)
    plt.legend(sorted_data.area_list[int(sorted_data.index[i])])
plt.legend(test1)
plt.show()
# Out:
# Top 5 Contries:-
# ----------------
# HartfordSpringfield
# SanFrancisco
# Philadelphia
# Sacramento
# Charlotte

# %% [markdown]
# ### Observation:-
#
# 1. Above Graph shows average prices during each year.
# (Here I have taken the graph of 5 cities whose avergare price cost of avocado was maximum)
# 2. From the above graph it can be inferred that the avocado prices were increased substantially in year 2017.
# 3. This price rise was mainly due to the low supply and high demand.
# (Source :- https://money.cnn.com/2017/09/09/news/economy/avocado-prices-soar/index.html)
# 4. Again in the 2018, the prices of Avocado droped below.

# %%
######## Lets Analyze the distribution of Avergae Price over all states #############
plt.figure(figsize=(15,15))
sns.barplot(x=sorted_data['area_list'], y=sorted_data['area_averageprice_ratio'])
plt.xticks(rotation= 90)
plt.xlabel('States')
plt.ylabel('Average Price of Avocado')
plt.title('Average Price/States')
# Out:
# Text(0.5, 1.0, 'Average Price/States')

# %% [markdown]
# - Above graph show the distribution of average prices of all states.
# - HartfordSpringfield, SanFrancisco, Philadelphia, Sacramento, Charlotte are the top five cities in which average price was higher(considering all 4 years) and average price of Avocado was minimum in Houston.
#
# Now lets check which type of avocado was more expensive and might be the cause for increase in average price. Below plotted bar graph will give more information of the same.

# %%
################### Plotting bar graph to find categorial distribution of average price ###################

######### Storing data of each year in different lists ##########
data_15=data[data.year==2015]
data_16=data[data.year==2016]
data_17=data[data.year==2017]
data_18=data[data.year==2018]
years = list(data.year.unique())
print("Years :- ",years)
data_15_con = data_15[data_15.type =='conventional'].AveragePrice.mean()
conventional_data = [float(data_15[data_15.type =='conventional'].AveragePrice.mean()),float(data_16[data_16.type =='conventional'].AveragePrice.mean()),float(data_17[data_17.type =='conventional'].AveragePrice.mean()),float(data_18[data_18.type =='conventional'].AveragePrice.mean())]
print("Conventional Avocados Average Price :- ",conventional_data)
organic_data = [float(data_15[data_15.type =='organic'].AveragePrice.mean()),float(data_16[data_16.type =='organic'].AveragePrice.mean()),float(data_17[data_17.type =='organic'].AveragePrice.mean()),float(data_18[data_18.type =='organic'].AveragePrice.mean())]
print("Organic Avocados Average Price :- ",organic_data)
###########################################
barWidth = 0.25
r1 = np.arange(len(conventional_data))
r2 = [x + barWidth for x in r1]
plt.bar(r1, conventional_data, color='blue', width=barWidth, edgecolor='black', label='Conventional')
plt.bar(r2, organic_data, color='orange', width=barWidth, edgecolor='black', label='Organic')
###
plt.xlabel('Year', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(conventional_data))], years)
plt.ylabel('Average Price', fontweight='bold')
###
plt.legend()
plt.show()
# Out:
# Years :-  [2015, 2016, 2017, 2018]
# Conventional Avocados Average Price :-  [1.0821109123434725, 1.1050715563506255, 1.2963624396665214, 1.1306007751937983]
# Organic Avocados Average Price :-  [1.6708411633109654, 1.5707558139534832, 1.7429995608256486, 1.568488372093023]

# %% [markdown]
# ### Observation :-
#
# 1. This bar graph show clearly that there was increase in the price of avocado in both categories(Conventioanl and Organic) in 2017 and this was maximum as compared to any other year.
#
# 2. Above comparision between average price of conventional and organic avocado also shows that avergae price of organic avocados were alwasy higher than the conventional and price difference between organic and conventional were maximum in 2015.

# %% [markdown]
# To check th effect of price rise on the consumption of the avocado, plotting total volume consumed

# %%
####### Distribution of total consumption of avocado in 5 states #############
data = data.rename(index=str, columns={"Total Volume" : "TotalVolume"})
area_list=list(data.region.unique())
unique_years = list(data.year.unique())
area_averageprice_ratio=[]
for i in area_list:
    x=data[data['region']==i]
    area_averageprice_rate=sum(x['TotalVolume'])/len(x)
    area_averageprice_ratio.append(area_averageprice_rate)
#area_averageprice_ratio = sorted(area_averageprice_ratio,reverse=True)
#print(area_averageprice_ratio)
df=pd.DataFrame({'area_list':area_list,'area_average_volume_ratio':area_averageprice_ratio})
new_index=df['area_average_volume_ratio'].sort_values(ascending=False).index.values
sorted_data=df.reindex(new_index)
plt.figure(figsize=(10,10))
test = []
print("Most consumed cities :-")
print("---------------------")
#print(sorted_data.area_list[int(sorted_data.index[0])])
for i in range(0,5):
    avg_column_cali= data[data["region"]==sorted_data.area_list[int(sorted_data.index[i])]]
    print(sorted_data.area_list[int(sorted_data.index[i])])
    #avg_column_cali = data[data["region"]==area_list[i]]                              
    #print(avg_column_cali)
    avg_per_year_cali = avg_column_cali.groupby('year').aggregate('mean')
    #data.year
    #print(avg_per_year_cali.AveragePrice)
    #print(avg_per_year_cali.TotalVolume)
    test.append(sorted_data.area_list[sorted_data.index[i]])
    plt.plot(unique_years,avg_per_year_cali.TotalVolume)
#print(test)
plt.legend(test)
plt.show()
# Out:
# Most consumed cities :-
# ---------------------
# LosAngeles
# DallasFtWorth
# Houston
# PhoenixTucson
# WestTexNewMexico

# %% [markdown]
# ### Observation :-
#
# From the above graph it can be concluded that the total volume consumed were maximum in LosAngeles. Although we got the top city in which the consumption of avocado were maximum, plotting the distribution graph of volume consumed in each state to have  more undersatinding about the distribution in each state.

# %%
######## Lets Analyze the distribution of Avergae volume consumed over all states #############
plt.figure(figsize=(13,10))
sns.barplot(x=sorted_data['area_list'], y=sorted_data['area_average_volume_ratio'])
plt.xticks(rotation= 90)
plt.xlabel('States')
plt.ylabel('Average Total Volume Rate')
plt.title('Average Volume Consume States')
# Out:
# Text(0.5, 1.0, 'Average Volume Consume States')

# %% [markdown]
# ### Observation :-
#
# - Above Graph shows the distribution of the total volume over all states. From above graph it can be concluded that the total volume consumed was very large in Los Angeles than any other states.
# - Now lets analysize the overall volume distribution of LosAngeles in terms of 'Conventional' and 'Organic', to see which type of Avocados are getting sold more.

# %%
############### Plotting bar graph bar to see the categorial distribution in LosAngeles #################
data_LA = data[(data["region"]=="LosAngeles")& (data.AveragePrice<2)]
#print(data_LA)
print(data_LA.type.value_counts())
plt.figure(figsize=(7,7))
plt.pie(data_LA.type.value_counts(),autopct='%1.2f%%')
plt.title('Type of Distribution')
# Out:
# conventional    169
# organic         152
# Name: type, dtype: int64
# Text(0.5, 1.0, 'Type of Distribution')

# %% [markdown]
# ### Observation :-
#
# - People in LosAngeles prefers conventional avocados over organic.
#
# Now lets find the relation between different features of avocado using Heat Map.

# %%
####### To chek the relation between two features, plotting heatmap ############
heat_map=plt.subplots(figsize=(8,8))
heat_map = sns.heatmap(data.corr(),annot = True, cmap="YlGnBu")
plt.show()

# %% [markdown]
# ### Observation :-
#
# - Total Bags of Avocados sold were closely related more to small bags, XLarge bags and Large bags respectively.
# - Also similar observation can be seen with respect to total volume consumed and small bags, XLarge bags and Large bags.
# - Hence cutomers preferences can be concluded as :-  __small bags > XLarge bags > Large bags__

# %% [markdown]
# ## 4. Preliminary Observation
#
# From above all visualizations below things can be concluded :-
#
# 1. Average price of th Avocado was maximum in 2017. The prices were drastically increased from 2016 to 2017. In 2018 average prices of Avocado again droped.
# 2. Average price were maximum in 'HartfordSpringfield' throght out the period and minimum in Houston.
# 3. It is also observed from the grouped bar graph that average price of organic avocado were more than the conventional type avocado. This is true as the cost required for manufacture of organic is more than the conventional and hence the average cost price of organic will be more than the conventional.
# (Source :- https://www.foxnews.com/food-drink/10-reasons-organic-food-is-so-expensive)
# 4. From the Average volume ratio graph, it can be inferred that the average volume of avocado consumed by the customers is maximum in Los Angeles. Now in order check whether customer prefers organic or conventional avocado, I plotted the pie chart of distribution of average volume consumed over avocado type for Los Angeles and found that customer prefers conventional avocado more than the organic avocados.
# 5. Possibly reason why customer prefers conventional over organic maybe the avergae price difference between these two types.
# 6. Customers prefers to buy small bags more than Xlarge and large bags.

# %% [markdown]
# ### Note :- I have made two notebook files for this assignment. 'Assignment_0_Classification-checkpoint' is the second file. At the end of second file, I have included 'Conclusion' and 'Reference' part.
